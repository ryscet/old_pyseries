# %%
# %matplotlib inline
#Change to %matplotlib notebook to be able to zoom, pan, etc the figure,
#inline is only used so the notebook can be exported to .rst format and hosted on readthedocs

# %%
import pyseries.LoadingData as loading
import pyseries.Preprocessing as prep
import pyseries.Analysis as analysis

# %%
channels = loading.Read_edf.Combine_EDF_XML('/Users/user/Desktop/Nagrania/ssvep_20hz/Agnieszka_03_06/',True)

n_samples_back = {"iti_screen": 0, "ssvep_ended": 500 * 10}
n_samples_forth = {"iti_screen":  500* 10, "ssvep_ended": 0}

slices = prep.MakeSlices.Make_Slices_for_Channel(channels, ['EEG O1', 'EEG P3', 'EEG C4'],n_samples_back, n_samples_forth)
# Out:
# EEG F3
# EEG F4
# EEG C3
# EEG C4
# EEG P3
# EEG P4
# EEG O1
# EEG O2
# EEG A2
# EEG Cz
# n samples 167272
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-cb58b645d941> in <module>()
#       4 n_samples_forth = {"iti_screen":  500* 10, "ssvep_ended": 0}
#       5
# ----> 6 slices = prep.MakeSlices.Make_Slices_for_Channel(channels, ['EEG 01', 'EEG P3', 'EEG C4'],n_samples_back, n_samples_forth)
#       7
#
# /Users/user/anaconda/lib/python3.5/site-packages/pyseries/Preprocessing/MakeSlices.py in Make_Slices_for_Channel(channels, ch_names, n_samples_back, n_samples_forth)
#      29
#      30     for name in ch_names:
# ---> 31         filtered = filters.bandpass(channels[name], 2, 30, df = 500)
#      32
#      33
#
# KeyError: 'EEG 01'

# %%
channels
# Out:
# {'EEG A2': array([  1.62542629e-07,   1.30828387e-06,  -2.21834401e-04, ...,
#           2.62391017e-05,   2.60659507e-05,   2.58789416e-05]),
#  'EEG C3': array([-0.00034038, -0.00398828, -0.02727805, ...,  0.00117261,
#          0.00116297,  0.00115274]),
#  'EEG C4': array([-0.00034038, -0.00398828, -0.02727805, ...,  0.00117241,
#          0.00116271,  0.00115242]),
#  'EEG Cz': array([-0.00034038, -0.00398828, -0.02727805, ...,  0.00113273,
#          0.00112613,  0.00111892]),
#  'EEG F3': array([-0.00034038, -0.00398828, -0.02727805, ...,  0.00122162,
#          0.00121177,  0.0012013 ]),
#  'EEG F4': array([-0.00034038, -0.00398828, -0.02739157, ...,  0.00117259,
#          0.00116311,  0.00115304]),
#  'EEG O1': array([-0.00034038, -0.00398828, -0.02727805, ...,  0.00111417,
#          0.00110779,  0.0011008 ]),
#  'EEG O2': array([-0.00034038, -0.00398828, -0.02727805, ...,  0.00110097,
#          0.00109463,  0.00108768]),
#  'EEG P3': array([-0.00034038, -0.00398828, -0.02727805, ...,  0.00119116,
#          0.00118085,  0.00116996]),
#  'EEG P4': array([-0.00034038, -0.00398828, -0.02727805, ...,  0.00110302,
#          0.00109671,  0.00108979]),
#  'events':                          trial          code      tmp1   tmp2
#  time
#  2016-06-03 14:41:01.012      0    iti_screen       NaN    NaN
#  2016-06-03 14:41:11.030      0     Only Look -1.975554    NaN
#  2016-06-03 14:41:24.064      0   ssvep_ended       NaN    NaN
#  2016-06-03 14:41:25.079      1    iti_screen       NaN    NaN
#  2016-06-03 14:41:35.092      1  Please Count  0.839459    NaN
#  2016-06-03 14:41:50.944      1   ssvep_ended       NaN    NaN
#  2016-06-03 14:42:02.472      1     responded  0.000000  317.0
#  2016-06-03 14:42:02.472      2    iti_screen       NaN    NaN
#  2016-06-03 14:42:12.484      2     Only Look  1.866791    NaN
